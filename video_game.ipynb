# %%
# %pip install regex
# Out:
# ...
#
# ...

# %%
import pandas as pd
import matplotlib as plt
import regex as re

# %%
videogame_df = pd.read_csv("Video_Games_Sales_as_at_22_Dec_2016.csv")
videogame_df
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %% [markdown]
# What is represented on each line?
# Each line is a game version of specific franchises depending on the platform it was sold on. The sales in the main video game markets and the critic scores are listed, as well as the developpers and publishers, genre and rating for usage

# %%
# Jeu vidéo le plus vendu
print(videogame_df['Global_Sales'].max())
videogame_df.loc[videogame_df['Global_Sales']==videogame_df['Global_Sales'].max()]['Name']
# Out:
# 82.53
# 0    Wii Sports
# Name: Name, dtype: object

# %%
# Platforme ayant vendu le plus de jeux
platform_df = videogame_df.groupby("Platform")['Global_Sales'].sum().sort_values(ascending=False)
platform_df
# Out:
# Platform
# PS2     1255.64
# X360     971.63
# PS3      939.43
# Wii      908.13
# DS       807.10
# PS       730.68
# GBA      318.50
# PS4      314.23
# PSP      294.30
# PC       260.30
# 3DS      259.09
# XB       258.26
# GB       255.45
# NES      251.07
# N64      218.88
# SNES     200.05
# GC       199.36
# XOne     159.44
# 2600      97.08
# WiiU      82.16
# PSV       54.12
# SAT       33.59
# GEN       30.78
# DC        15.97
# SCD        1.87
# NG         1.44
# WS         1.42
# TG16       0.16
# 3DO        0.10
# GG         0.04
# PCFX       0.03
# Name: Global_Sales, dtype: float64

# %%
# Rating Adults only
print(videogame_df.loc[videogame_df['Rating']=='AO'])
print(videogame_df.loc[videogame_df['Name']== 'Grand Theft Auto V'].groupby(videogame_df['Name']).value_counts())
# Out:
# Name                Name                Platform  Year_of_Release  Genre   Publisher             NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  Critic_Count  User_Score  User_Count  Developer       Rating
# Grand Theft Auto V  Grand Theft Auto V  PC        2015.0           Action  Take-Two Interactive  0.39      0.69      0.00      0.09         1.17          96.0          57.0          7.9         3756.0      Rockstar North  M         1
#                                         PS3       2013.0           Action  Take-Two Interactive  7.02      9.09      0.98      3.96         21.04         97.0          50.0          8.2         3994.0      Rockstar North  M         1
#                                         PS4       2014.0           Action  Take-Two Interactive  3.96      6.31      0.38      1.97         12.61         97.0          66.0          8.3         2899.0      Rockstar North  M         1
# ...

# %%
# Most sold game any platform
most_sold_games = videogame_df.groupby("Name")['Global_Sales'].sum().sort_values(ascending=False)
most_sold_games
# Out:
# Name
# Wii Sports                                                                        82.53
# Grand Theft Auto V                                                                56.57
# Super Mario Bros.                                                                 45.31
# Tetris                                                                            35.84
# Mario Kart Wii                                                                    35.52
#                                                                                   ...
# GoGo's Crazy Bones                                                                 0.01
# God Eater Off Shot: Tachibana Sakuya-hen Twin Pack & Animation Vol.7               0.01
# Fullmetal Alchemist: Trading Card Game                                             0.01
# Aa Megami-samaa                                                                    0.01
# Fujiko F. Fujio Characters: Great Assembly! Slightly Fantastic Slapstick Party     0.01
# ...

# %%
# Jeu Pokémon le plus vendu
pokemon_games = videogame_df[videogame_df['Name'].str.contains('pokemon', case=False, na=False)]
pokemon_games.sort_values('Global_Sales',ascending=False)
# Out:
#                                                     Name Platform  \
# 4                               Pokemon Red/Pokemon Blue       GB
# 12                           Pokemon Gold/Pokemon Silver       GB
# 20                         Pokemon Diamond/Pokemon Pearl       DS
# 25                         Pokemon Ruby/Pokemon Sapphire      GBA
# 27                           Pokemon Black/Pokemon White       DS
# 33                                   Pokemon X/Pokemon Y      3DS
# 46                  Pokemon HeartGold/Pokemon SoulSilver       DS
# 47             Pokemon Omega Ruby/Pokemon Alpha Sapphire      3DS
# 58                     Pokemon FireRed/Pokemon LeafGreen      GBA
# 83                       Pokemon Black 2/Pokemon White 2       DS
# 108                                     Pokemon Sun/Moon      3DS
# 168                                      Pokemon Stadium      N64
# 174                                      Pokemon Pinball       GB
# ...

# %%
videogame_df.sort_values('Critic_Score', ascending=False)
# Out:
#                                 Name Platform  Year_of_Release       Genre  \
# 57               Grand Theft Auto IV      PS3           2008.0      Action
# 5350                     SoulCalibur       DC           1999.0    Fighting
# 227         Tony Hawk's Pro Skater 2       PS           2000.0      Sports
# 51               Grand Theft Auto IV     X360           2008.0      Action
# 165               Grand Theft Auto V     XOne           2014.0      Action
# ...                              ...      ...              ...         ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0      Action
# 16715               LMA Manager 2007     X360           2006.0      Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0   Adventure
# 16717               Spirits & Spells      GBA           2003.0    Platform
# 16718            Winning Post 8 2016      PSV           2016.0  Simulation
#
# ...
